# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdHassanS/Pandas/blob/main/Pandas_Assessment_2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data1=pd.read_csv("/content/college_1.csv")
data2=pd.read_csv("/content/college_2.csv")

# %%
data1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
data2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df = pd.concat([data1,data2], ignore_index=True)

# %%
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
df.to_csv('Merged_file.csv')

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %%
df['Department'].value_counts()
# Out:
# Computer Science and Engineering             63
# Electronics and Communication Engineering    39
# Electronics and Electrical Engineering       17
# Name: Department, dtype: int64

# %%
g0=df[(df['Department']=='Computer Science and Engineering')]
g1=df[(df['Department']=="Electronics and Communication Engineering")]
g2=df[(df['Department']=='Electronics and Electrical Engineering')]

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
(df.loc[df["CodeKata Score"]>15000]).to_csv(" Exceeded expectations.csv")

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
(df.loc[(df["CodeKata Score"]>10000) & (df['CodeKata Score']<15000)]).to_csv("Reached_expectations.csv")

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
(df.loc[(df["CodeKata Score"]>7000) & (df['CodeKata Score']<10000)]).to_csv("Needs_Improvement.csv")

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
(df.loc[df["CodeKata Score"]<7000]).to_csv("Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
c=df['Previous Geekions'].mean()
g=df['CodeKata Score'].mean()
print("Previous Geekions vs CodeKata Score :", c, "vs", g)
# Out:
# Previous Geekions vs CodeKata Score : 3842.3529411764707 vs 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
print("No of students participated",len(df))
# Out:
# No of students participated 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
print("Average completion of python course :",df['python'].mean())
# Out:
# Average completion of python course : 54.35294117647059

# %%
print("Average completion of my_sql :",df['mysql'].mean())
# Out:
# Average completion of my_sql : 23.5

# %%
print("Average completion of python english :",df['python_en'].mean())
# Out:
# Average completion of python english : 29.65714285714286

# %%
print("Average completion of computational thinking :",df['computational_thinking'].mean())
# Out:
# Average completion of computational thinking : 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.nlargest(3, ['CodeKata Score'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.nlargest(3, ['Previous Geekions'])
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x=df['Department'].value_counts().rename_axis('No_of_departments').reset_index(name='counts')
x
# Out:
#                            No_of_departments  counts
# 0           Computer Science and Engineering      63
# 1  Electronics and Communication Engineering      39
# 2     Electronics and Electrical Engineering      17

# %%
labels=x.No_of_departments
values=x.counts
explode=(0.2,0,0)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.axis('equal')
ax.pie(values,labels=labels,autopct='%1.2f%%',shadow=True)
plt.legend(title='Index')
plt.title('Percentage of Departments')
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
s0=(g0.nlargest(1,['CodeKata Score']))
s1=(g1.nlargest(1,['CodeKata Score']))
s2=(g2.nlargest(1,['CodeKata Score']))

# %%
re=pd.concat([s0,s1,s2],ignore_index=True)
re
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1  Bodipudi Harini    -1.0   35.0              10040           10040
# 2    ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# 1  Electronics and Communication Engineering       0        0.0
# 2     Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                    -1.0
# 2                     9.0

# %%
x=re["Department"]
y=re["CodeKata Score"]
z=re["Name"]

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(x,y,width=0.4)
def addlabels(x,y,z):
    for i in range(len(z)):
        plt.text(i, y[i], y[i], ha = 'center')
addlabels(x,y,z)
